# %%
import tensorflow as tf
from tensorflow import keras


from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

sentences = [
    'I love my dog',
    'I love my cat',
    'You love my dog!',
    'Do you think my dog is amazing?'
]

# tokenizer = Tokenizer(num_words = 100)
# tokenizer.fit_on_texts(sentences)
# word_index = tokenizer.word_index
# print("word_index ", word_index)


# Word not in the tokenizer
tokenizer = Tokenizer(num_words = 100, oov_token="<OOV>")
tokenizer.fit_on_texts(sentences)
word_index = tokenizer.word_index
print("word_index", word_index)

sequences = tokenizer.texts_to_sequences(sentences)

padded = pad_sequences(sequences, maxlen=10)
print("\nWord Index = " , word_index)
print("\nSequences = " , sequences)
print("\nPadded Sequences:")
print(padded)
# Out:
# word_index {'<OOV>': 1, 'my': 2, 'love': 3, 'dog': 4, 'i': 5, 'you': 6, 'cat': 7, 'do': 8, 'think': 9, 'is': 10, 'amazing': 11}
#
# Word Index =  {'<OOV>': 1, 'my': 2, 'love': 3, 'dog': 4, 'i': 5, 'you': 6, 'cat': 7, 'do': 8, 'think': 9, 'is': 10, 'amazing': 11}
#
# Sequences =  [[5, 3, 2, 4], [5, 3, 2, 7], [6, 3, 2, 4], [8, 6, 9, 2, 4, 10, 11]]
#
# Padded Sequences:
# [[ 0  0  0  0  0  0  5  3  2  4]
#  [ 0  0  0  0  0  0  5  3  2  7]
#  [ 0  0  0  0  0  0  6  3  2  4]
#  [ 0  0  0  8  6  9  2  4 10 11]]

# %%
# Try with words that the tokenizer wasn't fit to
test_data = [
    'i really love my dog',
    'my dog loves my manatee'
]

test_seq = tokenizer.texts_to_sequences(test_data)
print("\nTest Sequence = ", test_seq)

padded = pad_sequences(test_seq)
print("\nPadded Test Sequence: ")
print(padded)
# Out:
# Test Sequence =  [[5, 1, 3, 2, 4], [2, 4, 1, 2, 1]]
#
# Padded Test Sequence:
# [[5 1 3 2 4]
#  [2 4 1 2 1]]

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/learning-datasets/sarcasm.json \
    -O /media/nsl47/hdd/AI_project/AI/NLP_Projects_with_BOOBRA/week1/dataset/sarcasm.json
# Out:
# --2024-05-09 16:44:19--  https://storage.googleapis.com/learning-datasets/sarcasm.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.167.155, 142.250.77.187, 142.250.67.59, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.167.155|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5643545 (5.4M) [application/json]
# Saving to: ‘/media/nsl47/hdd/AI_project/AI/NLP_Projects_with_BOOBRA/week1/dataset/sarcasm.json’
#
# /media/nsl47/hdd/AI 100%[===================>]   5.38M  4.08MB/s    in 1.3s
#
# 2024-05-09 16:44:21 (4.08 MB/s) - ‘/media/nsl47/hdd/AI_project/AI/NLP_Projects_with_BOOBRA/week1/dataset/sarcasm.json’ saved [5643545/5643545]
